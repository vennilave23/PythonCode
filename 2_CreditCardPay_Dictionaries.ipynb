# %%
cid = ['cid-0001', 'cid-0002', 'cid-0003', 'cid-0004', 'cid-0005'] # elements of lists are seperated by comma
credit_score = [650, 723, 581, 462, 773]   # list for storing credit score
age_of_customer = [25, 28, 38, 41, 62]     # list for storing age of the customer
debt_status = ['no-debt', 'no-debt', 'no-debt', 'in-debt', 'no-debt']  # list to store the debt status
no_of_existing_credit_cards = [3, 2, 4, 1, 2] # list to store the number of existing credit cards

# %%
# dictionary is created with key and value pairs
df1 = {
    'cust_id': cid,
    'cred_score': credit_score,
    'age': age_of_customer,
    'debt_status':debt_status,
    'curr_cred_cards':no_of_existing_credit_cards
}

df1
#print(df1)
# Out:
# {'cust_id': ['cid-0001', 'cid-0002', 'cid-0003', 'cid-0004', 'cid-0005'],
#  'cred_score': [650, 723, 581, 462, 773],
#  'age': [25, 28, 38, 41, 62],
#  'debt_status': ['no-debt', 'no-debt', 'no-debt', 'in-debt', 'no-debt'],
#  'curr_cred_cards': [3, 2, 4, 1, 2]}

# %%
df1['cust_id'][2]
for key, value in df1.items():  # Iterating through all the keys of dictionary, with values index as constant
    print(key ,value[3])
# Out:
# cust_id cid-0004
# cred_score 462
# age 41
# debt_status in-debt
# curr_cred_cards 1

# %%
# Installing the libraries with the specified version.
! python3 -m pip install pandas

#==1.5.3 -q --user
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.6-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vennilave23/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/vennilave23/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 26.2 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.4.6-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 23.1 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [numpy]  WARNING: The scripts f2py and numpy-config are installed in '/Library/Frameworks/Python.framework/Versions/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.6 pandas-3.0.3

# %%
# !pip3 install pandas numpy matplotlib
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (3.0.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (2.4.6)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vennilave23/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/vennilave23/Library/Python/3.14/lib/python/site-packages (from matplotlib) (26.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /Users/vennilave23/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 24.8 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 25.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.2.0-cp314-cp314-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 22.0 MB/s  0:00:00 eta 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pillow-12.2.0 pyparsing-3.3.2

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /usr/local/bin/python3
# 3.14.5 (v3.14.5:5607950ef23, May 10 2026, 07:38:09) [Clang 21.0.0 (clang-2100.0.123.102)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df1 = pd.DataFrame(df1)
df1
# Out:
# Matplotlib is building the font cache; this may take a moment.
#     cust_id  cred_score  age debt_status  curr_cred_cards
# 0  cid-0001         650   25     no-debt                3
# 1  cid-0002         723   28     no-debt                2
# 2  cid-0003         581   38     no-debt                4
# 3  cid-0004         462   41     in-debt                1
# 4  cid-0005         773   62     no-debt                2

# %%
df1.head(2)
# Out:
#     cust_id  cred_score  age debt_status  curr_cred_cards
# 0  cid-0001         650   25     no-debt                3
# 1  cid-0002         723   28     no-debt                2

# %%
df1.describe()
# Out:
#        cred_score        age  curr_cred_cards
# count    5.000000   5.000000         5.000000
# mean   637.800000  38.800000         2.400000
# std    122.289411  14.584238         1.140175
# min    462.000000  25.000000         1.000000
# 25%    581.000000  28.000000         2.000000
# 50%    650.000000  38.000000         2.000000
# 75%    723.000000  41.000000         3.000000
# max    773.000000  62.000000         4.000000

# %%
#df1.shape
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cust_id          5 non-null      str
#  1   cred_score       5 non-null      int64
#  2   age              5 non-null      int64
#  3   debt_status      5 non-null      str
#  4   curr_cred_cards  5 non-null      int64
# dtypes: int64(3), str(2)
# memory usage: 332.0 bytes
